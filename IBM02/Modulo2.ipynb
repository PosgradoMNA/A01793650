# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/A01793650/blob/main/IBM02/Modulo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis with Python, IBM
# ## **Módulo 2**
#
# ### A01793650
#
# **Jessica Paola Pulido Vásquez**
#
# [GitHub](https://github.com/PosgradoMNA/A01793650/blob/main/IBM02/Modulo1.ipynb)

# %% [markdown]
# # *Progress*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #*Quiz*
# **Question 1**
#
# What does CSV stand for?
#
# Comma-separated values
#
# **Question 2**
#
# In the data set, which of the following represents an attribute or feature?
#
# Column
#
# **Question 3**
#
# What is the name of what we want to predict?
#
# Target
#
# **Question 4**
#
# What is the command to display the first five rows of a dataframe df?
#
# df.head()
#
# **Question 5**
#
# What command do you use to get the data type of each row of the dataframe df?
#
# df.dtypes
#
# **Question 6**
#
# How do you get a statistical summary of a dataframe df?
#
# df.describe()
#
# **Question 7**
#
# If you use the method describe() without changing any of the arguments, you will get a statistical summary of all the columns of type "object".
#
# False
